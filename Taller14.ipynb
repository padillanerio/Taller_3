# %%
class Nodo:
    def __init__(self, dato):
        self.dato = dato
        self.ant = None
        self.sig = None

class Cancion:
    def __init__(self, nombre, duracion):
        self.nombre = nombre
        self.duracion = duracion
    def __str__(self):
        return f"{self.nombre} ({self.duracion})"
class ListaCanciones:
    def __init__(self):
        self.primero = None
        self.ultimo = None
    def insertar(self, cancion):
        nuevo = Nodo(cancion)
        if self.primero is None:
            self.primero = nuevo
            self.ultimo = nuevo
            nuevo.sig = nuevo
            nodo.ant = nuevo
        else:
            self.ultimo.sig = nuevo
            nuevo.ant = self.ultimo
            self.ultimo = nuevo
           self.ultimo.sig = self.primero
            self.primero.ant = self.ultimo


    def eliminar(self,actual):
      if self.primero is None:
        return
     #solo hay un nodo
        if self.primero == self.ultimo:
            self.primero = None
            self.ultimo = None
            return None

        # se unen  vecinos
        actual.ant.sig = actual.sig
        actual.sig.ant = actual.ant

      #si era frontera de la lista
        aux_retorno = actual.sig
        if actual == self.primero:
            self.primero = aux_retorno
        if actual == self.ultimo:
            self.ultimo = actual.ant

        return aux_retorno
      def pasar_cancion(self,actual):
        if self.primero is None:
            return
        actual=actual.sig
        return actual

# %% [markdown]
# ```pseudocode
# Clase ListaCanciones
#     // Constructor de la clase
#     funcion inicializar (self)
#         self.primero <- Nulo
#         self.ultimo <- Nulo
#
#     // Método para insertar una canción en la lista
#     funcion insertar (self, cancion)
#         nuevo <- Nodo(cancion)
#         Si self.primero es Nulo:
#             self.primero <- nuevo
#             self.ultimo <- nuevo
#             nuevo.sig <- nuevo
#             nuevo.ant <- nuevo
#         Sino:
#             self.ultimo.sig <- nuevo
#             nuevo.ant <- self.ultimo
#             self.ultimo <- nuevo
#             self.ultimo.sig <- self.primero
#             self.primero.ant <- self.ultimo
#
#     // Método para eliminar una canción de la lista
#     funcion eliminar (self, actual) -> Nodo
#         Si self.primero es Nulo:
#             retornar Nulo
#
#         // Solo hay un nodo en la lista
#         Si self.primero == self.ultimo:
#             self.primero <- Nulo
#             self.ultimo <- Nulo
#             retornar Nulo
#
#         // Unir los vecinos del nodo 'actual'
#         actual.ant.sig <- actual.sig
#         actual.sig.ant <- actual.ant
#
#         aux_retorno <- actual.sig
#
#         // Si el nodo eliminado era el primero
#         Si actual == self.primero:
#             self.primero <- aux_retorno
#         // Si el nodo eliminado era el último
#         Si actual == self.ultimo:
#             self.ultimo <- actual.ant
#
#         retornar aux_retorno
#
#     // Método para pasar a la siguiente canción en la lista
#     funcion pasar_cancion (self, actual) -> Nodo
#         Si self.primero es Nulo:
#             retornar Nulo
#         actual <- actual.sig
#         retornar actual
# ```
