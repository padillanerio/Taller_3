# %%
class Nodo:
  def __init__(self):
    self.dato=None
    self.sig=None
class Prediccciones:
  def __init__(self,modelo,prediccion,error):
    self.modelo=modelo
    self.prediccion=prediccion
    self.error=error
class ListaPredicciones:
  def __init__(self):
    self.primero=None
    self.ultimo=None
  def ModeloMenorError(self):
    if(self.primero is None):
      return None
    actual=self.primero
    menorError=actual.dato.error
    modeloMenorError=actual.dato.modelo
    while(actual != None):
        if(menorError > actual.dato.error):
          menorError=actual.dato.error
          modeloMenorError=actual.dato.modelo
        actual=actual.sig
    return modeloMenorError

# %% [markdown]
# ```markdown
# ## Pseudocódigo para la clase ListaPredicciones
#
# Clase ListaPredicciones
#   funcion __init__ (self):
#     self.primero <- Nulo
#     self.ultimo <- Nulo
#
#   funcion ModeloMenorError (self) -> modeloMenorError:
#     Si (self.primero es Nulo):
#       retornar Nulo
#
#     actual <- self.primero
#     menorError <- actual.dato.error
#     modeloMenorError <- actual.dato.modelo
#
#     Mientras (actual NO es Nulo):
#       Si (menorError > actual.dato.error):
#         menorError <- actual.dato.error
#         modeloMenorError <- actual.dato.modelo
#       actual <- actual.sig
#
#     retornar modeloMenorError
# ```
