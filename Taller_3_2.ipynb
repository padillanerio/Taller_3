# %% [markdown]
# ### Implementación Básica de una Lista Enlazada Dobles:
#
# o Desarrolla una clase ListaEnlazadaDoble que permita insertar, modificar,
# eliminar y buscar nodos.
#
# o Implementa métodos para recorrer la lista e imprimir sus elementos.
#
# o Realiza pruebas con diferentes tipos de datos (números, cadenas, objetos).

# %%
class node_doble:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None
    
class ListaEnlazadaDoble:
    def __init__(self):
        self.head = None
        self.tail = None


    def insertar(self,data):
        new_node = node_doble(data)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node

    def modificar(self,old_data,new_data):
        current = self.head
        while current is not None:
            if current.data == old_data:
                current.data = new_data
                return
            current = current.next

    def buscar(self,data):
        current = self.head
        while current is not None:
            if current.data == data:
                return current
            current = current.next
        return None
    
    def eliminar(self,data):
        current = self.buscar(data)

        if current is None:
            return f"el nodo con el dato {data} no existe"
        #! Eliminar el nodo encontrado
        #? Si el nodo a eliminar es el head o el tail, se deben actualizar los punteros correspondientes
        if current == self.head:
            #? si el nodo a eliminar es el unico nodo en la lista, se deben actualizar ambos punteros head y tail a None
            if self.head == self.tail:
                self.head = None
                self.tail = None
            else:
                #* si el nodo a eliminar es el head pero no es el unico nodo,
                #* se debe actualizar el puntero head al siguiente nodo 
                #* y establecer el puntero prev del nuevo head a None
                self.head = self.head.next
                self.head.prev = None
                current.next = None
        elif current == self.tail:
            self.tail = self.tail.prev
            self.tail.next = None
            current.prev = None
        else:
            #* si el nodo a eliminar no es ni el head ni el tail, 
            #* se deben actualizar los punteros next y prev de los nodos adyacentes 
            #* para omitir el nodo a eliminar
            current.prev.next = current.next
            current.next.prev = current.prev
            current.next = None
            current.prev = None
    

    def imprimir(self):
        current = self.head
        while current is not None:
            print(f"{current.data} -> ", end=" ")
            current = current.next
        print("None")

# %%
# PRUEBAS: numeros, cadenas y objetos
print("=== PRUEBAS CON NUMEROS ===")
lista_num = ListaEnlazadaDoble()
for n in [10, 20, 30, 40]:
    lista_num.insertar(n)

print("Lista inicial:")
lista_num.imprimir()

print("Buscar 30:", lista_num.buscar(30).data if lista_num.buscar(30) else None)

lista_num.modificar(20, 25)
print("Despues de modificar 20 -> 25:")
lista_num.imprimir()

lista_num.eliminar(10)
print("Despues de eliminar head (10):")
lista_num.imprimir()

lista_num.eliminar(40)
print("Despues de eliminar tail (40):")
lista_num.imprimir()

lista_num.eliminar(30)
print("Despues de eliminar nodo intermedio (30):")
lista_num.imprimir()


print("\n=== PRUEBAS CON CADENAS ===")
lista_str = ListaEnlazadaDoble()
for s in ["Ana", "Luis", "Marta", "Pablo"]:
    lista_str.insertar(s)

print("Lista inicial:")
lista_str.imprimir()

print("Buscar 'Marta':", lista_str.buscar("Marta").data if lista_str.buscar("Marta") else None)

lista_str.modificar("Luis", "Luisa")
print("Despues de modificar 'Luis' -> 'Luisa':")
lista_str.imprimir()

lista_str.eliminar("Ana")
print("Despues de eliminar head ('Ana'):")
lista_str.imprimir()

lista_str.eliminar("Pablo")
print("Despues de eliminar tail ('Pablo'):")
lista_str.imprimir()

lista_str.eliminar("Marta")
print("Despues de eliminar nodo intermedio ('Marta'):")
lista_str.imprimir()


print("\n=== PRUEBAS CON OBJETOS ===")
class Persona:
    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad

    def __eq__(self, other):
        return isinstance(other, Persona) and self.nombre == other.nombre and self.edad == other.edad

    def __repr__(self):
        return f"Persona({self.nombre}, {self.edad})"

p1 = Persona("Sofia", 21)
p2 = Persona("Carlos", 30)
p3 = Persona("Elena", 25)
p4 = Persona("Mario", 28)

lista_obj = ListaEnlazadaDoble()
for p in [p1, p2, p3, p4]:
    lista_obj.insertar(p)

print("Lista inicial:")
lista_obj.imprimir()

objetivo = Persona("Elena", 25)
encontrado = lista_obj.buscar(objetivo)
print("Buscar Persona('Elena', 25):", encontrado)

lista_obj.modificar(Persona("Carlos", 30), Persona("Carlos", 31))
print("Despues de modificar Carlos 30 -> 31:")
lista_obj.imprimir()

lista_obj.eliminar(Persona("Sofia", 21))
print("Despues de eliminar head (Sofia):")
lista_obj.imprimir()

lista_obj.eliminar(Persona("Mario", 28))
print("Despues de eliminar tail (Mario):")
lista_obj.imprimir()

lista_obj.eliminar(Persona("Elena", 25))
print("Despues de eliminar nodo intermedio (Elena):")
lista_obj.imprimir()
# Out:
# === PRUEBAS CON NUMEROS ===
# Lista inicial:
# 10 ->  20 ->  30 ->  40 ->  None
# Buscar 30: 30
# Despues de modificar 20 -> 25:
# 10 ->  25 ->  30 ->  40 ->  None
# Despues de eliminar head (10):
# 25 ->  30 ->  40 ->  None
# Despues de eliminar tail (40):
# 25 ->  30 ->  None
# Despues de eliminar nodo intermedio (30):
# 25 ->  None
#
# === PRUEBAS CON CADENAS ===
# Lista inicial:
# Ana ->  Luis ->  Marta ->  Pablo ->  None
# Buscar 'Marta': Marta
# Despues de modificar 'Luis' -> 'Luisa':
# Ana ->  Luisa ->  Marta ->  Pablo ->  None
# Despues de eliminar head ('Ana'):
# Luisa ->  Marta ->  Pablo ->  None
# Despues de eliminar tail ('Pablo'):
# Luisa ->  Marta ->  None
# Despues de eliminar nodo intermedio ('Marta'):
# Luisa ->  None
#
# === PRUEBAS CON OBJETOS ===
# Lista inicial:
# Persona(Sofia, 21) ->  Persona(Carlos, 30) ->  Persona(Elena, 25) ->  Persona(Mario, 28) ->  None
# Buscar Persona('Elena', 25): <__main__.node object at 0x0000020A62D94FE0>
# ...

# %% [markdown]
# ```pseudocodigo
# CLASE node_doble
#  funcion __init__(self, data)
#   self.data = data
#   self.next = Nulo
#   self.prev = Nulo
#  FIN CLASE
#
# CLASE ListaEnlazadaDoble
#  funcion __init__(self)
#   self.head = Nulo
#   self.tail = Nulo
#
#  funcion insertar(self, data)
#   new_node = node_doble(data)
#   Si self.head es Nulo
#    self.head = new_node
#    self.tail = new_node
#   Sino
#    self.tail.next = new_node
#    new_node.prev = self.tail
#    self.tail = new_node
#
#  funcion modificar(self, old_data, new_data)
#   current = self.head
#   Mientras current != Nulo
#    Si current.data == old_data
#     current.data = new_data
#     Retornar
#    current = current.next
#
#  funcion buscar(self, data)
#   current = self.head
#   Mientras current != Nulo
#    Si current.data == data
#     Retornar current
#    current = current.next
#   Retornar Nulo
#
#  funcion eliminar(self, data)
#   current = self.buscar(data)
#   Si current es Nulo
#    Retornar "el nodo con el dato " + data + " no existe"
#   Si current == self.head
#    Si self.head == self.tail
#     self.head = Nulo
#     self.tail = Nulo
#    Sino
#     self.head = self.head.next
#     self.head.prev = Nulo
#     current.next = Nulo
#   Sino Si current == self.tail
#    self.tail = self.tail.prev
#    self.tail.next = Nulo
#    current.prev = Nulo
#   Sino
#    current.prev.next = current.next
#    current.next.prev = current.prev
#    current.next = Nulo
#    current.prev = Nulo
#
#  funcion imprimir(self)
#   current = self.head
#   Mientras current != Nulo
#    Imprimir current.data
#    current = current.next
#   Imprimir "None"
#  FIN CLASE
#
# CLASE Persona
#  funcion __init__(self, nombre, edad)
#   self.nombre = nombre
#   self.edad = edad
#  funcion __eq__(self, other)
#   Retornar (other es Persona) Y (self.nombre == other.nombre) Y (self.edad == other.edad)
#  funcion __repr__(self)
#   Retornar "Persona(" + self.nombre + ", " + (self.edad) + ")"
#  FIN CLASE
#
# Imprimir "=== PRUEBAS CON NUMEROS ==="
#  lista_num = ListaEnlazadaDoble()
#  Para n en [10, 20, 30, 40]
#   lista_num.insertar(n)
#  Imprimir "Lista inicial:"
#  lista_num.imprimir()
#  Imprimir "Buscar 30:" + (lista_num.buscar(30).data si lista_num.buscar(30) != Nulo Sino "Nulo")
#  lista_num.modificar(20, 25)
#  Imprimir "Despues de modificar 20 -> 25:"
#  lista_num.imprimir()
#  lista_num.eliminar(10)
#  Imprimir "Despues de eliminar head (10):"
#  lista_num.imprimir()
#  lista_num.eliminar(40)
#  Imprimir "Despues de eliminar tail (40):"
#  lista_num.imprimir()
#  lista_num.eliminar(30)
#  Imprimir "Despues de eliminar nodo intermedio (30):"
#  lista_num.imprimir()
#
# Imprimir "=== PRUEBAS CON CADENAS ==="
#  lista_str = ListaEnlazadaDoble()
#  Para s en ["Ana", "Luis", "Marta", "Pablo"]
#   lista_str.insertar(s)
#  Imprimir "Lista inicial:"
#  lista_str.imprimir()
#  Imprimir "Buscar 'Marta':" + (lista_str.buscar("Marta").data si lista_str.buscar("Marta") != Nulo Sino "Nulo")
#  lista_str.modificar("Luis", "Luisa")
#  Imprimir "Despues de modificar 'Luis' -> 'Luisa':"
#  lista_str.imprimir()
#  lista_str.eliminar("Ana")
#  Imprimir "Despues de eliminar head ('Ana'):"
#  lista_str.imprimir()
#  lista_str.eliminar("Pablo")
#  Imprimir "Despues de eliminar tail ('Pablo'):"
#  lista_str.imprimir()
#  lista_str.eliminar("Marta")
#  Imprimir "Despues de eliminar nodo intermedio ('Marta'):"
#  lista_str.imprimir()
#
# Imprimir "=== PRUEBAS CON OBJETOS ==="
#  p1 = Persona("Sofia", 21)
#  p2 = Persona("Carlos", 30)
#  p3 = Persona("Elena", 25)
#  p4 = Persona("Mario", 28)
#  lista_obj = ListaEnlazadaDoble()
#  Para p en [p1, p2, p3, p4]
#   lista_obj.insertar(p)
#  Imprimir "Lista inicial:"
#  lista_obj.imprimir()
#  objetivo = Persona("Elena", 25)
#  encontrado = lista_obj.buscar(objetivo)
#  Imprimir "Buscar Persona('Elena', 25):" + (encontrado si encontrado != Nulo Sino "Nulo")
#  lista_obj.modificar(Persona("Carlos", 30), Persona("Carlos", 31))
#  Imprimir "Despues de modificar Carlos 30 -> 31:"
#  lista_obj.imprimir()
#  lista_obj.eliminar(Persona("Sofia", 21))
#  Imprimir "Despues de eliminar head (Sofia):"
#  lista_obj.imprimir()
#  lista_obj.eliminar(Persona("Mario", 28))
#  Imprimir "Despues de eliminar tail (Mario):"
#  lista_obj.imprimir()
#  lista_obj.eliminar(Persona("Elena", 25))
#  Imprimir "Despues de eliminar nodo intermedio (Elena):"
#  lista_obj.imprimir()
# ```
