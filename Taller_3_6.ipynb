# %% [markdown]
# Optimización de Búsquedas en Listas Enlazadas:
#
# Dada una lista enlazada de enteros, implementa una función que busque un número n más rápido utilizando un algoritmo de salto.
#
# Analiza el rendimiento de este algoritmo comparado con una búsqueda lineal.

# %%
from Clases_estructuras import lista_enlazada_simple

lista_enteros = lista_enlazada_simple()

for i in range(1, 1000):
    lista_enteros.agregar(i)



def buscar_con_algoritmo_de_salto(lista, entero):
    if lista.head is None:
        return f"La lista esta vacia."
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 for i in range(1, 1000):
#       6     lista_enteros.agregar(i)
# ----> 8 print(len(lista_enteros))  # Debería imprimir 999
#      10 def buscar_con_algoritmo_de_salto(lista, entero):
#      11     if lista.head is None:
#
# TypeError: object of type 'lista_enlazada_simple' has no len()
